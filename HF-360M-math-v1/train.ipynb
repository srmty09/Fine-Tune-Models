# %%
# !nvidia-smi

# %%
# !git clone https://github.com/unslothai/unsloth.git
# !cd unsloth

# %%
# !pip install -q -U unsloth_zoo
# !cd /kaggle/working/unsloth && pip install -q -e .

# %%
# !pip install -q -U unsloth unsloth_zoo bitsandbytes accelerate trl peft transformers datasets tqdm

# %%
# !pip install -q datasets

# %%
# !torchrun --nproc_per_node=2 /kaggle/working/unsloth/unsloth-cli.py \
  --model_name=HuggingFaceTB/SmolLM2-360M \
  --dataset=srmty/mixed-gpteacher-metamath-50k \
  --learning_rate=2e-5 \
  --max_seq_length=768 \
  --per_device_train_batch_size=8 \
  --gradient_accumulation_steps=8 \
  --max_steps=2200 \
  --save_model \
  --hub_path=srmty/smolLM2-360M-gpteacher-metamath-50k \
  --hub_token=""
